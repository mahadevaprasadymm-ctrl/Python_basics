# %% [markdown]
# <a href="https://colab.research.google.com/github/mahadevaprasadymm-ctrl/Python_basics/blob/main/Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HELLO 🌍")
# Out:
# HELLO 🌍

# %%
Name= input("Enter your name")
print ("Hello",Name)
print ("Welcome to python")
# Out:
# Enter your nameSushmitha
# Hello Sushmitha
# Welcome to python

# %%
print ("SUSHMITHA MAHADEV")
# Out:
# SUSHMITHA MAHADEV

# %%
name = "sushmitha"
year = "2007"

print ("HELLO",name)
print (year)
# Out:
# HELLO sushmitha
# 2007

# %%
Age=int(input("Enter your Age:"))

if Age>=19:
   print ("You can vote 🤝")
else:
   print ("come Again Next year 🖐️")
# Out:
# Enter your Age:19
# You can vote 🤝

# %%
def greet ():
    print ("Hello World")

greet()
# Out:
# Hello World

# %%
def greet (name):
    print ("Hello",name)

greet("Civil")
# Out:
# Hello Civil

# %%
def add,

# %%
Name= input("Enter your name")
print ("Hello",Name)
print ("Welcome to python")
# Out:
# Enter your nameSushmitha
# Hello Sushmitha
# Welcome to python

# %%
friends = {"M","N","S"}

for friend in friends:
      print (friend)
# Out:
# S
# N
# M

# %%
# !pip install ColabTurtlePlus

# %%
from ColabTurtlePlus.Turtle import Turtle,initializeTurtle

initializeTurtle()
c = Turtle()
c.circle(100)
c.done()
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path d="M 400.0 300.0 A 100 100 0 0 0 400.0 100.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 400.0 100.0 A 100 100 0 0 0 400.0 300.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/>
#
#
#         <g id="classic" visibility="visible" transform="rotate(-90,400.0,300.0) translate(400.0, 300.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:black;fill:black;stroke-width:1" />
# </g><g id="classic" visibility="visible" transform="rotate(-90,400.0,300.0) translate(400.0, 300.0)">
# <polygon points="-5,-4.5 0,-2.5 5,-4.5 0,4.5" transform="skewX(0) scale(1,1)" style="stroke:black;fill:black;stroke-width:1" />
# ...
